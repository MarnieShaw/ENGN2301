# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt #
import seaborn as sns
sns.set()
from scipy.stats import ttest_ind

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics

from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification

# %%
#df=pd.read_csv('health_insurance.csv')
df=pd.read_csv('~/work/teaching/ENGN2301/week 1/health_insurance.csv')

# %% [markdown]
# ### df creates a 'dataframe' in python. It's like a spreadsheet in excel, with rows and columns. Use df.head() to take a look at just the first few rows

# %%
df.head()
# Out:
#    age     sex    bmi  children smoker     region  charges  Unnamed: 7  \
# 0   19  female  27.90         0    yes  southwest  16885.0         NaN
# 1   31  female  25.74         0     no  southeast   3757.0         NaN
# 2   46  female  33.44         1     no  southeast   8241.0         NaN
# 3   37  female  27.74         3     no  northwest   7282.0         NaN
# 4   60  female  25.84         0     no  northwest  28923.0         NaN
#
#    Unnamed: 8
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %% [markdown]
# ### df.loc will give us particular columns and rows. Here we want the 'sex' column and only the females

# %%
df.loc[df["sex"] == 'female' ]
# Out:
#      age     sex     bmi  children smoker     region  charges  Unnamed: 7  \
# 0     19  female  27.900         0    yes  southwest  16885.0         NaN
# 1     31  female  25.740         0     no  southeast   3757.0         NaN
# 2     46  female  33.440         1     no  southeast   8241.0         NaN
# 3     37  female  27.740         3     no  northwest   7282.0         NaN
# 4     60  female  25.840         0     no  northwest  28923.0         NaN
# 5     62  female  26.290         0    yes  southeast  27809.0         NaN
# 6     56  female  39.820         0     no  southeast  11091.0         NaN
# 7     52  female  30.780         1     no  northeast  10797.0         NaN
# 8     60  female  36.005         0     no  northeast  13229.0         NaN
# 9     30  female  32.400         1     no  southwest   4150.0         NaN
# 10    34  female  31.920         1    yes  northeast  37702.0         NaN
# 11    59  female  27.720         3     no  southeast  14001.0         NaN
# 12    63  female  23.085         0     no  northeast  14452.0         NaN
# 13    55  female  32.775         2     no  northwest  12269.0         NaN
# 14    18  female  26.315         0     no  northeast   2198.0         NaN
# 15    19  female  28.600         5     no  southwest   4688.0         NaN
# 16    62  female  32.965         3     no  northwest  15612.0         NaN
# 17    24  female  26.600         0     no  northeast   3046.0         NaN
# 18    31  female  36.630         2     no  southeast   4950.0         NaN
# 19    37  female  30.800         2     no  southeast   6314.0         NaN
# 20    18  female  38.665         2     no  northeast   3393.0         NaN
# 21    28  female  34.770         0     no  northwest   3557.0         NaN
# 22    60  female  24.530         0     no  southeast  12630.0         NaN
# 23    18  female  35.625         0     no  northeast   2211.0         NaN
# 24    21  female  33.630         2     no  northwest   3580.0         NaN
# 25    40  female  28.690         3     no  northwest   8060.0         NaN
# 26    58  female  31.825         2     no  northeast  13607.0         NaN
# 27    53  female  22.880         1    yes  southeast  23245.0         NaN
# 28    34  female  37.335         2     no  northwest   5990.0         NaN
# 29    28  female  25.935         1     no  northwest   4134.0         NaN
# ..   ...     ...     ...       ...    ...        ...      ...         ...
# 632   32  female  29.735         0     no  northwest   4357.0         NaN
# 633   25  female  26.790         2     no  northwest   4189.0         NaN
# 634   48  female  33.330         0     no  southeast   8284.0         NaN
# 635   47  female  27.645         2    yes  northwest  24536.0         NaN
# 636   18  female  21.660         0    yes  northeast  14283.0         NaN
# 637   47  female  24.320         0     no  northeast   8535.0         NaN
# 638   28  female  17.290         0     no  northeast   3733.0         NaN
# 639   36  female  25.900         1     no  southwest   5472.0         NaN
# 640   38  female  19.950         2     no  northeast   7134.0         NaN
# 641   28  female  26.510         2     no  southeast   4340.0         NaN
# 642   19  female  25.745         1     no  northwest   2711.0         NaN
# 643   25  female  20.800         1     no  southwest   3209.0         NaN
# 644   24  female  27.720         0     no  southeast   2465.0         NaN
# 645   29  female  21.850         0    yes  northeast  16115.0         NaN
# 646   25  female  30.200         0    yes  southwest  33901.0         NaN
# 647   33  female  26.695         0     no  northwest   4571.0         NaN
# 648   19  female  34.700         2    yes  southwest  36398.0         NaN
# 649   30  female  23.655         3    yes  northwest  18766.0         NaN
# 650   19  female  20.600         0     no  southwest   1732.0         NaN
# 651   39  female  26.315         2     no  northwest   7202.0         NaN
# 652   42  female  40.370         2    yes  southeast  43896.0         NaN
# 653   42  female  32.870         0     no  northeast   7050.0         NaN
# 654   23  female  24.225         2     no  northeast  22396.0         NaN
# 655   57  female  25.740         2     no  southeast  12629.0         NaN
# 656   23  female  33.400         0     no  southwest  10796.0         NaN
# 657   52  female  44.700         3     no  southwest  11412.0         NaN
# 658   18  female  31.920         0     no  northeast   2206.0         NaN
# 659   18  female  36.850         0     no  southeast   1630.0         NaN
# 660   21  female  25.800         0     no  southwest   2008.0         NaN
# 661   61  female  29.070         0    yes  northwest  29141.0         NaN
#
#      Unnamed: 8
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# ..          ...
# 632         NaN
# 633         NaN
# 634         NaN
# 635         NaN
# 636         NaN
# 637         NaN
# 638         NaN
# 639         NaN
# 640         NaN
# 641         NaN
# 642         NaN
# 643         NaN
# 644         NaN
# 645         NaN
# 646         NaN
# 647         NaN
# 648         NaN
# 649         NaN
# 650         NaN
# 651         NaN
# 652         NaN
# 653         NaN
# 654         NaN
# 655         NaN
# 656         NaN
# 657         NaN
# 658         NaN
# 659         NaN
# 660         NaN
# 661         NaN
#
# [662 rows x 9 columns]

# %% [markdown]
# ### Remember our t-test where we compared males and females in terms of their charges? let's run that again here

# %%
t_statistic, p_value = ttest_ind(df.loc[df["sex"] == 'female' ].charges,df.loc[df["sex"] == 'male' ].charges, equal_var=False)

# %%
print(f't_statistic: {t_statistic}\np_value: {p_value}')
# Out:
# t_statistic: -2.100847823212175
# p_value: 0.03584453374892653

# %% [markdown]
# ### To do further analysis on our dataframe, just like in excel, we need to convert both the sex and smoker variables to dummy variables 0/1. Females == 1 and Smokers == 1

# %%
sex=pd.get_dummies(df['sex'])
sex=sex['female']
df['sex']=sex
df.head()
# Out:
#    age  sex    bmi  children smoker     region  charges  Unnamed: 7  \
# 0   19    1  27.90         0    yes  southwest  16885.0         NaN
# 1   31    1  25.74         0     no  southeast   3757.0         NaN
# 2   46    1  33.44         1     no  southeast   8241.0         NaN
# 3   37    1  27.74         3     no  northwest   7282.0         NaN
# 4   60    1  25.84         0     no  northwest  28923.0         NaN
#
#    Unnamed: 8
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
smoker=pd.get_dummies(df['smoker'])
smoker=smoker['yes']
df['smoker']=smoker

# %% [markdown]
# ### Now set up the data for model fitting, we want our X input data to be the age, sex, bmi and smoker columns of the dataframe and we want the y data to be the charges column of the dataframe

# %% [markdown]
# ### --> the X input data are the independent variables that we are using to predict the dependent variable Y

# %%
X = df[['age', 'sex', 'bmi', 'smoker']]
y = df['charges']

# %% [markdown]
# ### ok now we're going to split both X and y into training and test subsets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state = 42)

# %% [markdown]
# ### First fit linear regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### How well does the model fit? model.score gives the coefficient of determination R^2. For more info: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# ### first see R^2 on the training data (that was used to 'fit' the model i.e. determine the model parameters). Then see how that compares to the R^2 on the test data (that wasn't used to fit the model)

# %%
model.score(X_train, y_train)
# Out:
# 0.7559254490751786

# %%
model.score(X_test, y_test)
# Out:
# 0.7147529373724304

# %% [markdown]
# ### some more output about the model fit (all on the test data)

# %%
predicted = model.predict(X_test)
explained_variance=metrics.explained_variance_score(y_test, predicted)
mean_absolute_error=metrics.mean_absolute_error(y_test, predicted) 
mse=metrics.mean_squared_error(y_test, predicted) 
r2=metrics.r2_score(y_test, predicted)

print('explained_variance: ', round(explained_variance,4))    
print('r2: ', round(r2,4))
print('MAE: ', round(mean_absolute_error,4))
print('RMSE: ', round(np.sqrt(mse),4))
# Out:
# explained_variance:  0.7161
# r2:  0.7148
# MAE:  4548.9949
# RMSE:  6580.8501

# %% [markdown]
# ### we can use the model to predict the cost for a particular person e.g. a 37 year old non-smoking male, with BMI=30

# %%
some_person = {'age' : 37,
        'sex' : 0,
        'bmi' : 30,
        'smoker' : 0
       }
index = [1]
some_person = pd.DataFrame(some_person,index)
print(some_person)
prediction_some_person = model.predict(some_person)
print("Estimated charge for this person is: $",str(prediction_some_person.round(2))[1:-1])
# Out:
#    age  sex  bmi  smoker
# 1   37    0   30       0
# Estimated charge for this person is: $ 7492.43

# %% [markdown]
# ### Now fit a neural network N.B. this takes much longer

# %%
clf = MLPClassifier(random_state=1, max_iter=300).fit(X_train, y_train)
#clf = MLPClassifier(hidden_layer_sizes=(10,10), max_iter=300,activation = 'relu',solver='adam',random_state=1)
# Out:
# /Users/marnieshaw/anaconda/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
#clf.fit(X_train,y_train)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:617: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=300, random_state=1)

# %%
nn_predicted=clf.predict(X_test)

# %%
explained_variance=metrics.explained_variance_score(y_test, nn_predicted)
mean_absolute_error=metrics.mean_absolute_error(y_test, nn_predicted) 
mse=metrics.mean_squared_error(y_test, nn_predicted) 
r2=metrics.r2_score(y_test, nn_predicted)

print('explained_variance: ', round(explained_variance,4))    
print('r2: ', round(r2,4))
print('MAE: ', round(mean_absolute_error,4))
print('RMSE: ', round(np.sqrt(mse),4))
# Out:
# explained_variance:  0.6594
# r2:  0.6582
# MAE:  4238.5037
# RMSE:  7204.1386
